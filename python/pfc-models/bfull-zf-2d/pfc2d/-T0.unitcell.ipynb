# %%
import source.initialize_system
import source.pfc_binary_full
import importlib

importlib.reload(source.initialize_system)
importlib.reload(source.pfc_binary_full)
from source.pfc_binary_full import pfcModel as pfc

import cupy as cp

# %%
sim = pfc()
sim.initialize_parms({"lx": 10, "ly":20})
sim.parms.mx
