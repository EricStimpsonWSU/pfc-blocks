# %%
# load bampl2048eps03g05w03aAB05bAB0noise10_1_A0B0n0_t0.dat into numpy array

import numpy as np
import matplotlib.pyplot as plt

filename = 'bampl2048eps03g05w03aAB05bAB0noise10_1_A0B0n0_t10000.dat'
data0 = np.loadtxt(filename, skiprows=1)

# %%
data0
# Out:
# array([[ 1.00000000e+00,  1.52298283e-09,  1.62703609e-08, ...,
#          2.05210772e-09, -4.43894477e-01, -4.43351280e-01],
#        [ 2.00000000e+00,  1.52521467e-09,  1.62750458e-08, ...,
#          2.05137871e-09, -4.43895478e-01, -4.43352516e-01],
#        [ 3.00000000e+00,  1.52746318e-09,  1.62798566e-08, ...,
#          2.05068526e-09, -4.43896472e-01, -4.43353778e-01],
#        ...,
#        [ 2.04600000e+03,  1.51640624e-09,  1.62570596e-08, ...,
#          2.05451157e-09, -4.43891426e-01, -4.43347720e-01],
#        [ 2.04700000e+03,  1.51857858e-09,  1.62613679e-08, ...,
#          2.05367413e-09, -4.43892450e-01, -4.43348881e-01],
#        [ 2.04800000e+03,  1.52077239e-09,  1.62658015e-08, ...,
#          2.05287312e-09, -4.43893467e-01, -4.43350068e-01]])

# %%
# plot column 1 vs column 0
plt.plot(data0[:,0], data0[:,1])

# %%
# plot column 1 vs column 0
plt.plot(data0[:,0], data0[:,4])

# %%
# plot column 1 vs column 0
plt.plot(data0[:,0], data0[:,7])

# %%
# plot column 1 vs column 0
plt.plot(data0[:,0], data0[:,8])

# %%
filename = 'bampl2048eps03g05w03aAB05bAB0noise10_4_A0B0n0_t10000.dat'
data90 = np.loadtxt(filename, skiprows=1)

# %%
# repeat all plots for data90
plt.plot(data90[:,0], data90[:,1])
plt.plot(data0[:,0], data90[:,1])

# %%
# plot with plotly go traces
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=data0[:,0], y=data0[:,1], mode='lines', name='data0 1'))
fig.add_trace(go.Scatter(x=data0[:,0], y=data0[:,4], mode='lines', name='data0 4'))

fig.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(data90[:,0], data90[:,4])
plt.plot(data90[:,0], data90[:,4])

# %%
plt.plot(data90[:,0], data90[:,7])

# %%
plt.plot(data90[:,0], data90[:,8])
